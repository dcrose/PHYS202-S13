# %% [markdown]
# Project Euler Problem 25
# =
# The Fibonacci sequence is defined by the recurrence relation:
#
# $F_n = F_{n+1} + F_{n+2}$
#
# where $F_1 = 1$
#
# and $F_2 = 1$.
#
# Hence the first 12 terms will be:
#
# $F_1$ = 1
#
# $F_2$ = 1
#
# $F_3$ = 2
#
# $F_4$ = 3
#
# $F_5$ = 5
#
# $F_6$ = 8
#
# $F_7$ = 13
#
# $F_8$ = 21
#
# $F_9$ = 34
#
# $F_{10}$ = 55
#
# $F_{11}$ = 89
#
# $F_{12}$ = 144
#
# The 12th term, $F_{12}$, is the first term to contain three digits.
#
# What is the first term in the Fibonacci sequence to contain 1000 digits?

# %%
def Fib(n): # Testing the Sequence
    if n == 1:
        return 1
    elif n == 2:
        return 1
    else:
        return (Fib(n-1) + Fib(n-2))

# %%
Fib(12)
# Out:
# 144

# %%
print len(str(Fib(12)))
# Out:
# 3

# %%
Fib1 = 1
Fib2 = 1
index = 2
whatwewant = 0
while True: # While this is true, do the following:
    whatwewant = Fib1 + Fib2 # Define the sequence
    Fib1 = Fib2              #Rename each to the previous, so when the loop is running it restarts with the correct values.
    Fib2 = whatwewant
    index += 1                   # Makes the index increase by 1 for each iteration
    if len(str(whatwewant)) == 1000: #When it hits the value we want,
        print whatwewant
        print "It is the " + str(index) + " Fibonacci number." #Print the number
        break                        #And stop the loop
"""This is much more efficient that using a for loop, or really anything else. The for loop has some fatal flaws that inhibit its use."""
# Out:
# ...
# It is the 4782 Fibonacci number.
# 'This is much more efficient that using a for loop, or really anything else. The for loop has some fatal flaws that inhibit its use.'

# %% [markdown]
# Test Case
# -

# %%
def Fibonacci(n):
    Fib1 = 1
    Fib2 = 1
    index = 2
    whatwewant = 0
    while True: # While this is true, do the following:
        whatwewant = Fib1 + Fib2 # Define the sequence
        Fib1 = Fib2              #Rename each to the previous, so when the loop is running it restarts with the correct values.
        Fib2 = whatwewant
        index += 1                   # Makes the index increase by 1 for each iteration
        if len(str(whatwewant)) == n: #When it hits the value we want,
            print whatwewant
            print "It is the " + str(index) + " Fibonacci number." #Print the number
            break                        #And stop the loop

# %%
Fibonacci(10000)
# Out:
# ...
# It is the 47847 Fibonacci number.
