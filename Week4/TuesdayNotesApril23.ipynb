# %% [markdown]
# Electric Dipole Potential
# =

# %% [markdown]
# #$V(x,y) = \frac{kq}{\sqrt{x^2+(y-d)^2}}-\frac{kq}{\sqrt{x^2+(y+d)^2}}$

# %%
# Create an x-y grid covering the plane -2<x<2 and -2<y<2
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-2.,2.,dx),arange(-2.,2.,dy))
print x.ndim
print y.shape
# Out:
# 2
# (67, 67)

# %%
k = 1; q = 1; d = 1
V=(k*q/(x**2+(y-d)**2)**(1/2.))-(k*q/(x**2+(y+d)**2)**(1/2.))

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x,y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.prism_r)



cb = fig.colorbar(p,shrink=0.5)
cset = ax.contour(x,y,V,zdir="z",offset=-40.,cmap=cm.prism_r)
cset = ax.contour(x,y,V,zdir="x",offset=-2.,cmap=cm.prism_r)
cset = ax.contour(x,y,V,zdir="y",offset=-2.,cmap=cm.prism_r)

# %%
levels = array([8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8])
contour(x,y,V,levels,cmap=cm.jet)
show()

# %% [markdown]
# Exercise 1:
# -
# Make a 3-D plot of the function:
# $G(x,y) = e^{(-x^2-y^2)}$
#
# over the range -6 < (x,y) < 6 using 51 bins in x and 51 bins in y.

# %%
dx = 0.236
dy = 0.236
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))
print x.ndim
print y.shape
# Out:
# 2
# (51, 51)

# %%
G = e**(-x**2-y**2)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x,y,G,rstride=1,cstride=1,linewidth=0,cmap=cm.jet)
cb = fig.colorbar(p,shrink=0.5)
cset = ax.contour(x,y,G,array([0.,0.2,0.4,0.6,0.8]),zdir="x",offset=-6.,cmap=cm.jet)

# %% [markdown]
# Exercise 2:
# -
# Determing the electric potential for a quadrupole consisting of q = -1.0 nC at both (x = ±2, y = 0) and q = +1.0 nC at both (x = 0, y = ±2).
#
# Make a surface plot and a contour plot on the range -4 < (x,y) < 4 using 101 bins in x and 101 bins in y.

# %%
dx = 0.0795
dy = 0.0795
x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))
print x.ndim
print y.shape
# Out:
# 2
# (101, 101)

# %%
k = 8.98755*10**9 # Nm^2/C^2
q1 = 1*10**(-9)
q2 = -1*10**(-9)
d = 2
d2 = -2
V =(k*q/(x**2+(y-d)**2)**(1/2.))-(k*q/(x**2+(y+d)**2)**(1/2.)) +(k*q2/(y**2+(x-d)**2)**(1/2.))-(k*q2/(y**2+(x+d)**2)**(1/2.))

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x,y,Vxy,rstride=1,cstride=1,linewidth=0,cmap=cm.jet)



#cb = fig.colorbar(p,shrink=0.5)
#cset = ax.contour(x,y,V,zdir="z",offset=-40.,cmap=cm.prism_r)
#cset = ax.contour(x,y,V,zdir="x",offset=-2.,cmap=cm.prism_r)
#cset = ax.contour(x,y,V,zdir="y",offset=-2.,cmap=cm.prism_r)

# %%
levels = array([8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8])
contour(x,y,V,levels,cmap=cm.jet)
show()
# My contour plot died. Worked in class perfectly.

# %% [markdown]
# Exercise 3:
# -
# Part a

# %%
def pointPotential(x,y,q,posx,posy):
    Vxy = (k*q/(x**2+(y-d)**2)**(1/2.))
    v = 1/(sqrt((x-posx)**2+(y-posy)**2))
    return Vxy
def dipolePotential(x,y,q,d):
    Vxy = (k*q/(x**2+(y-d)**2)**(1/2.))-(k*q/(x**2+(y+d)**2)**(1/2.))
    return Vxy
# Out:
# 6.35515755125
# [[ 2.00967728  2.02166081  2.03348644 ...,  2.04127584  2.02956293
#    2.01768318]
#  [ 2.0340488   2.04647634  2.05874548 ...,  2.06682993  2.05467423
#    2.04235074]
#  [ 2.05893995  2.07183224  2.08456596 ...,  2.09295968  2.08033992
#    2.06755171]
#  ...,
#  [ 4.47946358  4.61708165  4.76339197 ...,  4.86617505  4.71360594
#    4.57028205]
#  [ 4.48816829  4.62661528  4.77386304 ...,  4.87734029  4.72375141
#    4.57952812]
#  [ 4.49287651  4.6317733   4.77952999 ...,  4.88338426  4.72924156
#    4.58453008]]
