# %% [markdown]
# Ordinary Differential Equations
# =
# Approximate Solution
# -

# %%
g = 9.8 #m/s^2
l = 0.5 #m
th0 = 20.*pi/180 # 20 degrees, but need be in radians.

t = arange(0.,10.01,0.01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)

plot(t,theta_app(t))
show()

# %%
def deriv(theta_current,t): # Return derivatives of the array theta
    g = 9.8
    l = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array([dtheta,domega])

# %%
from scipy.integrate import odeint
#odeint?

# %%
t = arange(0.,10.01,0.01)

omega0 = 0. #starting from rest, omega = 0
theta_init = array([th0,omega0]) # initial values, th0 from before...

theta = odeint(deriv,theta_init,t) # pass the function deriv to the solver...

# %%
theta.shape
# Out:
# (1001, 2)

# %%
plot(t,theta_app(t),"b-", t,theta[:,0],"r--")
show()

# %%
th0 = 50.*pi/180 # 50 degrees

theta_init = array([th0,omega0]) # initial values
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),"b-",t,theta[:,0],"r--")
show()

# %% [markdown]
# That diverges quite quickly.

# %% [markdown]
# Exercises
# -
#
# ####1: see what happens to the period of the pendulum as you change the initial angle of release. Plot $\theta$ vs $t$ for 5 different initial angles, $\theta_0$ , spanning 0 to $\pi$ . (i.e. 0, $\pi$/4 , $\pi$/2 , 3$\pi$/4 , and $\pi$ ). Put them alll on the same plot. What happens to the period of the pendulum as the initial angle increases from $\pi$/4 to 3$\pi$/4 ? What happens to the trajectory when the initial angle is 0 and $\pi$ ?

# %%
figure(figsize=(12,8))

th0 = 0 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ = 0")

th0 = pi/4 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ = $\frac{\pi}{4}$")

th0 = pi/2 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ = $\frac{\pi}{2}$")

th0 = 3.*pi/4 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ = $3\frac{\pi}{4}$")

th0 = pi 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ = $\pi$")

legend(loc="lower right")
show()

# %% [markdown]
# As the angle increases from $\pi$/4 to 3$\pi$/4 , everything increases. Amplitude and period and... (etc.)

# %% [markdown]
# ####2: Look carefully at the time dependence ( $\theta$ vs. $t$ and $\omega$ vs. $t$ ) and the phase plot ( $\omega$ vs. $\theta$ ) for $\theta_0$ = 0.95$\pi$ . What is going on in these figures?

# %%
figure(figsize(12,8))

th0 = 0.95*pi 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(t,theta[:,0],label=r"$\theta$ vs. $t$")
plot(t,theta[:,1],label=r"$\omega$ vs. $t$")

legend(loc="upper left")
show()

# %%
figure(figsize(12,8))

th0 = 0.95*pi 
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plot(theta[:,0],theta[:,1],label=r"$\theta$ vs. $\omega$")


legend(loc="upper left")
show()

# %% [markdown]
# Analysis: shit's goin down.
